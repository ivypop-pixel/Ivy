# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import your exoplanet data.csv file as a pandas DataFrame. To avoid an error, include
df =pd.read_csv("PS_2026.04.15_19.00.44.csv",
comment = "#")
df
# Out:
#          pl_name   hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0        7 CMa c      7 CMa             0        1        2  Radial Velocity
# 1        7 CMa c      7 CMa             1        1        2  Radial Velocity
# 2       DMPP-1 b     DMPP-1             1        1        4  Radial Velocity
# 3       DMPP-1 b     DMPP-1             0        1        4  Radial Velocity
# 4       DMPP-1 c     DMPP-1             1        1        4  Radial Velocity
# ..           ...        ...           ...      ...      ...              ...
# 578    bet Pic c    bet Pic             0        1        2  Radial Velocity
# 579    bet Pic c    bet Pic             1        1        2  Radial Velocity
# 580    bet Pic c    bet Pic             0        1        2  Radial Velocity
# 581  eps Ind A b  eps Ind A             1        3        1  Radial Velocity
# 582  eps Ind A b  eps Ind A             0        3        1  Radial Velocity
#
# ...

# %%
df.shape #583 rows, 92 columns
# Out:
# (583, 92)

# %%
df.columns
# sy_vmagerr2,st_tefferr2, sy_dist,sy_vmag,ra
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
# ...

# %%
# # Planet Name-pl_name, planate name
# # hostname-	Host Name, Stellar name most commonly used in the literature
# discoverymethod- Discovery-how it was discvovered
# st_spectype-	Spectral, Classification of the star based on their spectral characteristics following the Morgan-Keenan system
# pl_eqt- Equilibrium Temperature, The equilibrium temperature of the planet as modeled by a black body heated only by its host star,
# pl_massj-Planet Mass , amount of atter in the jupiter

# %%
smaller_df = df[['pl_name', 'hostname', 'discoverymethod','st_spectype','pl_eqt','pl_bmassj']]
new_df=smaller_df.dropna()
new_df
# Out:
#          pl_name   hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 3       DMPP-1 b     DMPP-1  Radial Velocity        F8 V   877.0   0.076362
# 5       DMPP-1 c     DMPP-1  Radial Velocity        F8 V  1239.0   0.030205
# 7       DMPP-1 d     DMPP-1  Radial Velocity        F8 V  1632.0   0.010540
# 8       DMPP-1 e     DMPP-1  Radial Velocity        F8 V  1314.0   0.012994
# 10      DMPP-2 b     DMPP-2  Radial Velocity        F5 V  1000.0   0.437000
# ..           ...        ...              ...         ...     ...        ...
# 561   WASP-185 b   WASP-185          Transit        G0 V  1160.0   0.980000
# 565   WASP-190 b   WASP-190          Transit     F6 IV-V  1500.0   1.000000
# 569   WASP-192 b   WASP-192          Transit        G0 V  1620.0   2.300000
# 572       XO-7 b       XO-7          Transit        G0 V  1743.0   0.709000
# 581  eps Ind A b  eps Ind A  Radial Velocity        K5 V   275.0   6.310000
#
# [70 rows x 6 columns]

# %%
new_df.shape #70 rows, 6 columns
# Out:
# (70, 6)

# %%
new_df.head(5)
# Out:
#      pl_name hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 3   DMPP-1 b   DMPP-1  Radial Velocity        F8 V   877.0   0.076362
# 5   DMPP-1 c   DMPP-1  Radial Velocity        F8 V  1239.0   0.030205
# 7   DMPP-1 d   DMPP-1  Radial Velocity        F8 V  1632.0   0.010540
# 8   DMPP-1 e   DMPP-1  Radial Velocity        F8 V  1314.0   0.012994
# 10  DMPP-2 b   DMPP-2  Radial Velocity        F5 V  1000.0   0.437000

# %%
new_df.tail(5)
# Out:
#          pl_name   hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 561   WASP-185 b   WASP-185          Transit        G0 V  1160.0      0.980
# 565   WASP-190 b   WASP-190          Transit     F6 IV-V  1500.0      1.000
# 569   WASP-192 b   WASP-192          Transit        G0 V  1620.0      2.300
# 572       XO-7 b       XO-7          Transit        G0 V  1743.0      0.709
# 581  eps Ind A b  eps Ind A  Radial Velocity        K5 V   275.0      6.310

# %%
new_df.columns
# Out:
# Index(['pl_name', 'hostname', 'discoverymethod', 'st_spectype', 'pl_eqt',
#        'pl_bmassj'],
#       dtype='object')

# %%
df.value_counts("discoverymethod")
# Transit,Radial Velocity,Microlensing,Imaging,Transit Timing Variations,Eclipse Timing Variations,Disk Kinematics
# Out:
# discoverymethod
# Transit                      392
# Radial Velocity              118
# Microlensing                  61
# Imaging                        6
# Transit Timing Variations      3
# Eclipse Timing Variations      2
# Disk Kinematics                1
# Name: count, dtype: int64

# %%
# most is transit, 392
# least is DK-1
 # Transit-when a planet passes between a star and its observer
# Radial Velocity,-wobble method measures changes in a star's
# Microlensing, technique that detects exoplanets
# Imaging,-blocks the bright lighht
# Transit Timing Variations,
# Eclipse Timing Variations,
# Disk Kinematics

# %%
fig, axes =plt.subplots(figsize=(8,6))
x=df["pl_bmassj"]
y=df["pl_eqt"]
axes.scatter(x,y, color= 'red')
# # for method in df[discoverymethod].unique(): i think i had to use this but i dont know how to

axes.set_title("planet mass vs equil")
axes.set_ylabel("pl_eqt")
axes.set_xlabel("pl_bmass")
# plt.legend()
plt.show()
# For each discovery method, use a different color.

# %%
axes.scatter(np.log(df.loc[x,y,], color= 'red')) #i dont know how to make thedots different for each method 


# /3. Duplicate your previous plot but change both axes to a logarithmic scale.
# Hint: Call np.log()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 axes.scatter(np.log(df.loc[x,y,], color= 'red'))
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
# Based on your plot, are exoplanets found by the imaging method more likely to be massive or small?
# -bigger

# %%
greater_5 =df[df['pl_bmassj']>5]
coldest = greater_5.loc[greater_5['pl_eqt'].idxmin()]
print(coldest)
# Out:
# pl_name           eps Ind A b
# hostname            eps Ind A
# default_flag                1
# sy_snum                     3
# sy_pnum                     1
#                      ...
# sy_gaiamagerr1       0.007374
# sy_gaiamagerr2      -0.007374
# rowupdate          2024-08-07
# pl_pubdate            2024-09
# releasedate        2024-08-07
# Name: 581, Length: 92, dtype: object

# %%
# 1.eps Ind A
# 2. incex 581
# equilibrium temperature:?
# What is it’s mass (in Jupiter masses)?-6.31
# What type of star is it orbiting? Is it a sun-like star? i think so

# %%
mass_value = coldest_row['pl_bmassj']
mass_value
# Out:
# np.float64(6.31)

# %%
greater_5 =df[df['pl_bmassj']>5]
coldest = greater_5.loc[greater_5['pl_eqt'].idxmin()]
print(coldest)
# Out:
# pl_name           eps Ind A b
# hostname            eps Ind A
# default_flag                1
# sy_snum                     3
# sy_pnum                     1
#                      ...
# sy_gaiamagerr1       0.007374
# sy_gaiamagerr2      -0.007374
# rowupdate          2024-08-07
# pl_pubdate            2024-09
# releasedate        2024-08-07
# Name: 581, Length: 92, dtype: object

# %%
# 4.5 Check Your Answer
# title =A temperate super-Jupiter imaged with JWST in the mid-infrared
# there is a new planet that is rlly bright, giant planet
# Does your answer match the exoplanet? not reallly
# What is special about the planet you found?- its really big
# • Do the mass and equilibrium temperature match what the paper reported? If not, what
# are the differences?
# the mass is way off, im not sire wshy`s

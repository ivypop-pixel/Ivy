# %%
import matplotlib.pyplot as plt
import from astropy.io import fits
import numpy as np

# %%
fits_files=[
    "M13_0001.fits"
    "M13_0002.fits"
    "M13_0003.fits"
    "M13_0004.fits"
    "M13_0005.fits"
]
headers = []
data_list = []

for i in fits_files:
    with fits.open(i) as hdul:
        header = hdul[0].header
        data = hdul[0].data
        data_list.append(data)
        print(f"Loaded {filename}")
print(f" files loaded: {len(data_list)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 12
#       9 data_list = []
#      11 for i in fits_files:
# ---> 12     with fits.open(i) as hdul:
#      13         header = hdul[0].header
#      14         data = hdul[0].data
#
# File /opt/anaconda3/lib/python3.13/site-packages/astropy/io/fits/hdu/hdulist.py:224, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     221 if not name:
#     222     raise ValueError(f"Empty filename: {name!r}")
# --> 224 return HDUList.fromfile(
#     225     name,
#     226     mode,
#     227     memmap,
#     228     save_backup,
#     229     cache,
#     230     lazy_load_hdus,
#     231     ignore_missing_simple,
#     232     use_fsspec=use_fsspec,
#     233     fsspec_kwargs=fsspec_kwargs,
# ...
